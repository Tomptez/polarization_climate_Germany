# %% [markdown]
# # Create final Bundestag dataset as a combination from open discourse and GermaParl

# %%
import pandas as pd
from tqdm import tqdm
import plotly.express as px

# setup
pd.set_option("display.max_colwidth", 2000)
pd.set_option("display.max_rows", 50)

# %%
# get speeches
dfg = pd.read_feather("data/germaparl.feather")
# use only from 19th legislative period
dfg = dfg[dfg["electoral_term"] == 19]
# Select only speeches by mp or government
dfg = dfg[(dfg["role"]=="mp") | (dfg["role"]=="government")]
dfg = dfg.sort_values(by=['speech_id'])
dfg.shape
#dfg.head(1)
# Out:
# (40075, 18)

# %%
dfg[dfg.speech.str.contains("\n", case=False)]
# Out:
# Empty DataFrame
# Columns: [aid, speech_id, name, position, party, role, group, who, speech, agenda_no, agenda_type, description_agenda, title, electoral_term, session, session_id, date, url]
# Index: []

# %%
dfo = pd.read_feather("data/open_discourse_1819.feather")
dfo["speech_content"] = dfo["speech_content"].str.normalize('NFKD')
# use only from 18th legislative period
dfo = dfo[dfo["electoral_term"] == 18]
# Select only speeches by mp or government
dfo = dfo[(~dfo["position_short"].isin(['Presidium of Parliament', 'Guest', 'Not found']))]
dfo = dfo.sort_values(by=['id_x'])
dfo.shape
#dfo.head(1)
# Out:
# (27833, 16)

# %%
# convert open discourse positions to roles from GermaParl
roles = {"Member of Parliament": "mp", "Minister": "government", "Chancellor": "government", "Secretary of State": "government"}
dfo["role"] = dfo.position_short.map(roles)

# %%
dfo = dfo.rename({'speech_content':'speech', 'document_url':'url'}, axis='columns')

# %%
dfo = dfo[["name", "electoral_term", "session", "party", "speech", "role", "date", "url"]]
dfg = dfg[["name", "electoral_term", "session", "party", "speech", "role", "date", "url"]]

# %%
df = pd.concat([dfo, dfg])

# %%
df[df.speech.str.len() < 110].sample(40)
# Out:
#                           name  electoral_term  session      party  \
# 11558             Katja Dörner              18       57     GRUENE
# 74846        Annalena Baerbock              19      239     GRUENE
# 11598           Horst Seehofer              19       41        CSU
# 52260     Maria Klein-Schmeink              18      243     GRUENE
# 47631      Gabriele Hiller-Ohm              19      158        SPD
# 24375           Mahmut Özdemir              19       83        SPD
# 9007          Peter Boehringer              19       34        AfD
# 19932            Katja Kipping              18       94  DIE LINKE
# 12692  Heinz Joachim Barchmann              18       61        SPD
# 42138           Christian Kühn              19      140     GRUENE
# 34770      Grigorios Aggelidis              19      116        FDP
# 40482            Volkmar Klein              19      135        CDU
# 17591           Christian Jung              19       60        FDP
# 62655           Mahmut Özdemir              19      204        SPD
# 71361               Dirk Wiese              19      229        SPD
# 39562       Karl Heinz Brunner              18      184        SPD
# 61648              Helge Lindh              19      202        SPD
# 69048  Kirsten Kappert-Gonther              19      223     GRUENE
# 8134                Jens Maier              19       30        AfD
# 3465             Carina Konrad              19       14        FDP
# 55689               Peter Weiß              19      183        CDU
# 45632             Ole Schröder              18      214  not found
# 22035            Silvia Breher              19       75        CDU
# 71361  https://www.bundestag.de/resource/blob/843228/e7bdd113f0a25fec02ef7c61d2dcdda3/19229-data.xml
# 39562                                              https://dip21.bundestag.de/dip21/btp/18/18184.pdf
# 61648  https://www.bundestag.de/resource/blob/814422/d22be85d41309ffb1905787368f39a98/19202-data.xml
# 69048  https://www.bundestag.de/resource/blob/836686/228a15c20af03bc1914b542fa80d0f8b/19223-data.xml
# 8134   https://www.bundestag.de/resource/blob/553876/400e0eb4b39f4d3e6146e1e8de99ce6f/19030-data.xml
# 3465   https://www.bundestag.de/resource/blob/544630/58474a2534987e1c4b5b6c50e5d833ed/19014-data.xml
# 55689  https://www.bundestag.de/resource/blob/798236/ee037da35ea0afefb372c290bd05fe3e/19183-data.xml
# 45632                                              https://dip21.bundestag.de/dip21/btp/18/18214.pdf
# 22035  https://www.bundestag.de/resource/blob/588928/87b7d62ef70f4397a73ff42d504bd3fe/19075-data.xml
# 33843                                              https://dip21.bundestag.de/dip21/btp/18/18160.pdf
# 38726                                              https://dip21.bundestag.de/dip21/btp/18/18180.pdf
# 14264                                              https://dip21.bundestag.de/dip21/btp/18/18069.pdf
# 66861  https://www.bundestag.de/resource/blob/830648/914ffd5c32d6a9d5b1a07c93eb456af6/19217-data.xml
# 38505  https://www.bundestag.de/resource/blob/668710/43acc93d3d760e1a2d90c9f25440d57a/19127-data.xml
# 11662  https://www.bundestag.de/resource/blob/562712/fec082c4eb4bcd90d11773852b87524c/19042-data.xml
# 73115  https://www.bundestag.de/resource/blob/847180/2455dd20de2c5c8de9755ada1ae18fbc/19233-data.xml
# 42193                                              https://dip21.bundestag.de/dip21/btp/18/18197.pdf
# 7640                                               https://dip21.bundestag.de/dip21/btp/18/18037.pdf
# 2124                                               https://dip21.bundestag.de/dip21/btp/18/18012.pdf
# 25309                                              https://dip21.bundestag.de/dip21/btp/18/18120.pdf
# 56703  https://www.bundestag.de/resource/blob/802712/b9b525cdd1c7c6a4283ef18531608355/19186-data.xml
# 33492                                              https://dip21.bundestag.de/dip21/btp/18/18158.pdf
# 61284  https://www.bundestag.de/resource/blob/814066/b6d69d8a9d971b3d1a9f1a55d0f05593/19201-data.xml
# 16880  https://www.bundestag.de/resource/blob/574826/0e3659e11c1c3cdbfa621369cd16735a/19058-data.xml
# 61632  https://www.bundestag.de/resource/blob/814422/d22be85d41309ffb1905787368f39a98/19202-data.xml
# 16314  https://www.bundestag.de/resource/blob/573822/41ceeb62a53b1b7c6a247aabf38f8136/19056-data.xml

# %%
print(dfg.shape, dfo.shape)
print(df.shape)
# Out:
# (40075, 8) (27833, 8)
# (67908, 8)

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df = df.reset_index(drop=True)

# %%
df["speech_id"] = df.index + 1

# %%
df.reset_index(drop=True).to_feather("data/Bundestag1819.feather")
